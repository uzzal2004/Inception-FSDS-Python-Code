# %%
1. Email Validator (String Filtering + Loops)
�
� Real-world use: Used in signup forms or data cleaning tasks.
Task:
Check if a given email is valid — must contain “@” and end with “.com” or “.org”.
Example:
Input: hello@inceptionbd.com
Output: Valid Email

# %%
email = input("Enter your email address: ")
if "@" in email and (email.endswith(".com") or email.endswith(".org")):  # considering case sensitiveness
    print("Valid Email")
else:
  print("Invalid Email")
# Out:
# Enter your email address: 2@r.COM
# Invalid Email

# %% [markdown]
# 2. Count Word Frequency in Customer Reviews
# �
# � Real-world use: Analyzing reviews or comments in text analytics.
# Task:
# Given a review text, count how many times each word appears (ignore case).
# Example:
# Input: "This product is good and this service is excellent"
# Output: {'this': 2, 'product': 1, 'is': 2, 'good': 1, 'and': 1, 'service': 1, 'excellent': 1}

# %%
text = input("Enter your text: ").lower()  # ignore case
words = text.split() #Split the text into words

word_count = {}

for word in words:        #Loop each word
    if word in word_count:
       word_count[word] += 1
    else:
       word_count[word] = 1
print(word_count)
# Out:
# Enter your text: This product is good and this service is excellent
# {'this': 2, 'product': 1, 'is': 2, 'good': 1, 'and': 1, 'service': 1, 'excellent': 1}

# %% [markdown]
# 3. Password Strength Checker
# �
# � Real-world use: Used in user authentication systems.
# Task:
# Check if a password is strong — must have at least one uppercase, one lowercase, one digit, and one
# special character.
# Example:
# Input: "Hello@123"
# Output: Strong Password

# %%
password = input("Enter your password: ")
special_chars = "!@#$%^&*()_+-=[]{}|;:,.<>/?`~"  #ignoring length check as it is not mentioned in the tasks.

if (any(secret in special_chars for secret in password) and    # password strength
    any(secret.islower() for secret in password) and
    any(secret.isupper() for secret in password) and
    any(secret.isdigit() for secret in password)):

    print("Strong Password")
else:
    print("Weak Password")
# Out:
# Enter your password: Hello@123
# Strong Password

# %% [markdown]
# 4. Username Generator
# �
# � Real-world use: Automatically create usernames for users.
# Task:
# Take user’s full name and generate a short username.
# Rules: first 3 letters of first name + last 3 letters of last name + random number (use loops only).
# Example:
# Input: "Mamun Malitha"
# Output: mamitha57

# %%
import random
full_name = input("Enter your full name: ")   # considering only two words names.
first_name, last_name = full_name.split()
i = 0
for i in range(1):  # loop but take only one number.
    i = random.randint(10, 99)
    username = first_name[:3] + last_name[-3:] + str(i)
    print(username)
# Out:
# Enter your full name: dfsfsfds htfhsfdf
# dfsfdf85

# %% [markdown]
# 5. SMS Word Counter
# �
# � Real-world use: Used in messaging apps or social media post limit check.
# Task:
# Count how many characters and words are in a message, and tell if it exceeds 160 characters (SMS limit).
# Example:
# Input: "This is a demo message."
# Output: Words = 5, Characters = 23, Status = Within Limit

# %%
message = input("Enter your message: ")

alph_count = len(message)  # alphabet count

words = message.split()
word_count = len(words) # word count

if alph_count > 160:
    status = "Limit Exceeded"
else:
    status = "Within Limit"

print(f'Words = {word_count} , Characters = {alph_count}, Status = {status}' )
# Out:
# Enter your message: Now let me create a comprehensive README file:Perfect! I've created a comprehensive MySQL MCP server for you
# Words = 17 , Characters = 108, Status = Within Limit

# %% [markdown]
# 6. Remove Duplicates from Contact List
# �
# � Real-world use: Data cleaning in CRM or user databases.
# Task:
# Given a list of names (comma separated), remove duplicates.
# Example:
# Input: "Rahim, Karim, Rahim, Sultana"
# Output: "Rahim, Karim, Sultana"

# %%
#contact_names = ["Rahim", "Karim", "Rahim", "Sultana"]
contact_names = input("Given a list of names (comma separated): ")
names = contact_names.split()
unique_names = []
for name in names:
    if name not in unique_names:
        unique_names.append(name)
print(unique_names)
# Out:
# Given a list of names (comma separated): Rahim, Karim, Rahim, Sultana
# ['Rahim,', 'Karim,', 'Sultana']

# %% [markdown]
# 7. Detect Suspicious Words in Text (Moderation)
# �
# � Real-world use: Used in chat moderation or email filtering.
# Task:
# If any “banned” words like ['spam', 'scam', 'fake'] are found in a text, print “Warning”.
# Example:
# Input: "This is a scam offer"
# Output: Warning: Suspicious content detected

# %%
banned = ['spam', 'scam', 'fake']
text = input("Enter your text: ")
words = text.split()
for word in words:
    if word in banned:
        print("Warning: Suspicious content detected")
# Out:
# Enter your text: This is a scam offer
# Warning: Suspicious content detected

# %% [markdown]
# 8. Invoice Code Formatter
# �
# � Real-world use: Formatting IDs or codes in finance or ERP systems.
# Task:
# Given an invoice number like 23, generate code in the format INV00023.
# Example:
# Input: 23
# Output: INV00023

# %%
invoice_number = input("Enter your invoice number: ")
invoice_code = "INV" + invoice_number.zfill(5)
print(invoice_code)
# Out:
# Enter your invoice number: 65
# INV00065

# %% [markdown]
# 9. Count Hashtags and Mentions (Social Media Analytics)
# �
# � Real-world use: Used in analyzing social media posts.
# Task:
# Count how many hashtags (#) and mentions (@) appear in a post.
# Example:
# Input: "Check out #AIWorkshop and follow @inceptionbd"
# Output: Hashtags = 1, Mentions = 1

# %%
post = input("Enter the post: ")

hashtag_count = post.count('#')
mention_count = post.count('@')

print(f"Hashtags = {hashtag_count}, Mentions = {mention_count}")
# Out:
# Enter the post: Check out #AIWorkshop and follow @inceptionbd
# Hashtags = 1, Mentions = 1

# %% [markdown]
# 10. Word Reversal for Data Encryption
# �
# � Real-world use: Simple text obfuscation or playful encoding.
# Task:
# Reverse each word in a sentence while keeping word order the same.
# Example:
# Input: "AI is fun"
# Output: "IA si nuf"

# %%
sentence = input("Enter a sentence: ")

words = sentence.split()

reversed_words = []
for word in words:
    reversed_words.append(word[::-1])

reversed_sentence = " ".join(reversed_words)

print(reversed_sentence)
# Out:
# Enter a sentence: i am learning python
# i ma gninrael nohtyp
